# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## In this notebook we're going to explore and anaylsis the data of Taylor Swift's songs
#
# Dataset [Link](https://www.kaggle.com/datasets/jarredpriester/taylor-swift-spotify-dataset/data)

# %%
df = pd.read_csv("taylor_swift_spotify.csv")
df
# Out:
#      Unnamed: 0                                           name  \
# 0             0         Welcome To New York (Taylor's Version)
# 1             1                 Blank Space (Taylor's Version)
# 2             2                       Style (Taylor's Version)
# 3             3            Out Of The Woods (Taylor's Version)
# 4             4  All You Had To Do Was Stay (Taylor's Version)
# ..          ...                                            ...
# 525         525                                       Our Song
# 526         526                  I'm Only Me When I'm With You
# 527         527                                      Invisible
# 528         528                         A Perfectly Good Heart
# 529         529           Teardrops on My Guitar - Pop Version
#
#                                 album release_date  track_number  \
# 0    1989 (Taylor's Version) [Deluxe]   2023-10-27             1
# 1    1989 (Taylor's Version) [Deluxe]   2023-10-27             2
# 2    1989 (Taylor's Version) [Deluxe]   2023-10-27             3
# 3    1989 (Taylor's Version) [Deluxe]   2023-10-27             4
# 4    1989 (Taylor's Version) [Deluxe]   2023-10-27             5
# ..                                ...          ...           ...
# 525                      Taylor Swift   2006-10-24            11
# 526                      Taylor Swift   2006-10-24            12
# 527                      Taylor Swift   2006-10-24            13
# 528                      Taylor Swift   2006-10-24            14
# 529                      Taylor Swift   2006-10-24            15
#
#                          id                                   uri  \
# 0    4WUepByoeqcedHoYhSNHRt  spotify:track:4WUepByoeqcedHoYhSNHRt
# 1    0108kcWLnn2HlH2kedi1gn  spotify:track:0108kcWLnn2HlH2kedi1gn
# 2    3Vpk1hfMAQme8VJ0SNRSkd  spotify:track:3Vpk1hfMAQme8VJ0SNRSkd
# 3    1OcSfkeCg9hRC2sFKB4IMJ  spotify:track:1OcSfkeCg9hRC2sFKB4IMJ
# 4    2k0ZEeAqzvYMcx9Qt5aClQ  spotify:track:2k0ZEeAqzvYMcx9Qt5aClQ
# ..                      ...                                   ...
# 525  15DeqWWQB4dcEWzJg15VrN  spotify:track:15DeqWWQB4dcEWzJg15VrN
# 526  0JIdBrXGSJXS72zjF9ss9u  spotify:track:0JIdBrXGSJXS72zjF9ss9u
# 527  5OOd01o2YS1QFwdpVLds3r  spotify:track:5OOd01o2YS1QFwdpVLds3r
# 528  1spLfUJxtyVyiKKTegQ2r4  spotify:track:1spLfUJxtyVyiKKTegQ2r4
# 529  4pJi1rVt9GNegU9kywjg4z  spotify:track:4pJi1rVt9GNegU9kywjg4z
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.009420         0.757   0.610          0.000037    0.3670    -4.840
# 1        0.088500         0.733   0.733          0.000000    0.1680    -5.376
# 2        0.000421         0.511   0.822          0.019700    0.0899    -4.785
# 3        0.000537         0.545   0.885          0.000056    0.3850    -5.968
# 4        0.000656         0.588   0.721          0.000000    0.1310    -5.579
# ..            ...           ...     ...               ...       ...       ...
# 525      0.111000         0.668   0.672          0.000000    0.3290    -4.931
# 526      0.004520         0.563   0.934          0.000807    0.1030    -3.629
# 527      0.637000         0.612   0.394          0.000000    0.1470    -5.723
# 528      0.003490         0.483   0.751          0.000000    0.1280    -5.726
# 529      0.040200         0.459   0.753          0.000000    0.0863    -3.827
#
#      speechiness    tempo  valence  popularity  duration_ms
# 0         0.0327  116.998    0.685          79       212600
# 1         0.0670   96.057    0.701          79       231833
# 2         0.0397   94.868    0.305          80       231000
# 3         0.0447   92.021    0.206          79       235800
# 4         0.0317   96.997    0.520          78       193289
# ..           ...      ...      ...         ...          ...
# 525       0.0303   89.011    0.539          76       201106
# 526       0.0646  143.964    0.518          61       213053
# 527       0.0243   96.001    0.233          58       203226
# 528       0.0365  156.092    0.268          56       220146
# 529       0.0537  199.997    0.483          57       179066
#
# [530 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'album', 'release_date', 'track_number', 'id',
#        'uri', 'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'popularity',
#        'duration_ms'],
#       dtype='object')

# %% [markdown]
# ## About Dataset
# - name : the name of the song
#
# - album : the name of the album
#
# - release_date : the day month and year the album was released
#
# - track number : the order the song appears on the album
#
# - id : the Spotify id for the song
#
# - uri : the Spotify uri for the song
#
# - acousticness : A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# - danceability : Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# - energy : Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# - instrumentalness : Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# - liveness : Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# - loudness : The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# - speechiness : detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# - tempo : The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# - valence : A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# - popularity : the popularity of the song from 0 to 100
#
# - duration_ms : The duration of the track in milliseconds.

# %% [markdown]
# ## Data Cleaning

# %%
# Because we don't need uri and id of songs in the spotify, we drop them from the dataset

df = df.drop(['uri', 'id'], axis=1)
df
# Out:
#      Unnamed: 0                                           name  \
# 0             0         Welcome To New York (Taylor's Version)
# 1             1                 Blank Space (Taylor's Version)
# 2             2                       Style (Taylor's Version)
# 3             3            Out Of The Woods (Taylor's Version)
# 4             4  All You Had To Do Was Stay (Taylor's Version)
# ..          ...                                            ...
# 525         525                                       Our Song
# 526         526                  I'm Only Me When I'm With You
# 527         527                                      Invisible
# 528         528                         A Perfectly Good Heart
# 529         529           Teardrops on My Guitar - Pop Version
#
#                                 album release_date  track_number  \
# 0    1989 (Taylor's Version) [Deluxe]   2023-10-27             1
# 1    1989 (Taylor's Version) [Deluxe]   2023-10-27             2
# 2    1989 (Taylor's Version) [Deluxe]   2023-10-27             3
# 3    1989 (Taylor's Version) [Deluxe]   2023-10-27             4
# 4    1989 (Taylor's Version) [Deluxe]   2023-10-27             5
# ..                                ...          ...           ...
# 525                      Taylor Swift   2006-10-24            11
# 526                      Taylor Swift   2006-10-24            12
# 527                      Taylor Swift   2006-10-24            13
# 528                      Taylor Swift   2006-10-24            14
# 529                      Taylor Swift   2006-10-24            15
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.009420         0.757   0.610          0.000037    0.3670    -4.840
# 1        0.088500         0.733   0.733          0.000000    0.1680    -5.376
# 2        0.000421         0.511   0.822          0.019700    0.0899    -4.785
# 3        0.000537         0.545   0.885          0.000056    0.3850    -5.968
# 4        0.000656         0.588   0.721          0.000000    0.1310    -5.579
# ..            ...           ...     ...               ...       ...       ...
# 525      0.111000         0.668   0.672          0.000000    0.3290    -4.931
# 526      0.004520         0.563   0.934          0.000807    0.1030    -3.629
# 527      0.637000         0.612   0.394          0.000000    0.1470    -5.723
# 528      0.003490         0.483   0.751          0.000000    0.1280    -5.726
# 529      0.040200         0.459   0.753          0.000000    0.0863    -3.827
#
#      speechiness    tempo  valence  popularity  duration_ms
# 0         0.0327  116.998    0.685          79       212600
# 1         0.0670   96.057    0.701          79       231833
# 2         0.0397   94.868    0.305          80       231000
# 3         0.0447   92.021    0.206          79       235800
# 4         0.0317   96.997    0.520          78       193289
# ..           ...      ...      ...         ...          ...
# 525       0.0303   89.011    0.539          76       201106
# 526       0.0646  143.964    0.518          61       213053
# 527       0.0243   96.001    0.233          58       203226
# 528       0.0365  156.092    0.268          56       220146
# 529       0.0537  199.997    0.483          57       179066
#
# [530 rows x 16 columns]

# %% [markdown]
# ## Information about dataset

# %%
df.info() # We see that there is no null value in the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        530 non-null    int64
#  1   name              530 non-null    object
#  2   album             530 non-null    object
#  3   release_date      530 non-null    object
#  4   track_number      530 non-null    int64
#  5   acousticness      530 non-null    float64
#  6   danceability      530 non-null    float64
#  7   energy            530 non-null    float64
#  8   instrumentalness  530 non-null    float64
#  9   liveness          530 non-null    float64
#  10  loudness          530 non-null    float64
#  11  speechiness       530 non-null    float64
#  12  tempo             530 non-null    float64
#  13  valence           530 non-null    float64
#  14  popularity        530 non-null    int64
#  15  duration_ms       530 non-null    int64
# dtypes: float64(9), int64(4), object(3)
# memory usage: 66.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  track_number  acousticness  danceability      energy  \
# count  530.000000    530.000000    530.000000    530.000000  530.000000
# mean   264.500000     11.184906      0.319247      0.585285    0.574609
# std    153.142091      7.981060      0.327043      0.113121    0.191565
# min      0.000000      1.000000      0.000184      0.243000    0.118000
# 25%    132.250000      5.000000      0.036250      0.516000    0.443000
# 50%    264.500000     10.000000      0.165000      0.595500    0.589500
# 75%    396.750000     15.000000      0.653000      0.653000    0.729750
# max    529.000000     46.000000      0.971000      0.897000    0.950000
#
#        instrumentalness    liveness    loudness  speechiness       tempo  \
# count        530.000000  530.000000  530.000000   530.000000  530.000000
# mean           0.004005    0.163492   -7.505434     0.055889  122.332311
# std            0.033163    0.142263    2.939040     0.070300   30.000272
# min            0.000000    0.035700  -17.932000     0.023100   68.097000
# 25%            0.000000    0.096600   -9.222000     0.030325   96.939500
# 50%            0.000002    0.115000   -7.012000     0.037300  119.030000
# 75%            0.000056    0.163000   -5.361750     0.055225  143.934250
# max            0.488000    0.931000   -1.909000     0.912000  208.918000
#
#           valence  popularity    duration_ms
# count  530.000000  530.000000     530.000000
# mean     0.397379   63.615094  239978.624528
# std      0.199589   15.590790   46119.983031
# min      0.037400   32.000000   83253.000000
# 25%      0.230000   50.000000  211813.000000
# 50%      0.385500   68.000000  235273.000000
# 75%      0.535000   76.000000  260361.000000
# max      0.943000   99.000000  613026.000000

# %%
# Change release date to release year and month
df['release_date'] = pd.to_datetime(df['release_date'])

# extract the day, month, and year components
df['release_month'] = df['release_date'].dt.month
df['release_year'] = df['release_date'].dt.year
df
# Out:
#      Unnamed: 0                                           name  \
# 0             0         Welcome To New York (Taylor's Version)
# 1             1                 Blank Space (Taylor's Version)
# 2             2                       Style (Taylor's Version)
# 3             3            Out Of The Woods (Taylor's Version)
# 4             4  All You Had To Do Was Stay (Taylor's Version)
# ..          ...                                            ...
# 525         525                                       Our Song
# 526         526                  I'm Only Me When I'm With You
# 527         527                                      Invisible
# 528         528                         A Perfectly Good Heart
# 529         529           Teardrops on My Guitar - Pop Version
#
#                                 album release_date  track_number  \
# 0    1989 (Taylor's Version) [Deluxe]   2023-10-27             1
# 1    1989 (Taylor's Version) [Deluxe]   2023-10-27             2
# 2    1989 (Taylor's Version) [Deluxe]   2023-10-27             3
# 3    1989 (Taylor's Version) [Deluxe]   2023-10-27             4
# 4    1989 (Taylor's Version) [Deluxe]   2023-10-27             5
# ..                                ...          ...           ...
# 525                      Taylor Swift   2006-10-24            11
# 526                      Taylor Swift   2006-10-24            12
# 527                      Taylor Swift   2006-10-24            13
# 528                      Taylor Swift   2006-10-24            14
# 529                      Taylor Swift   2006-10-24            15
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.009420         0.757   0.610          0.000037    0.3670    -4.840
# 1        0.088500         0.733   0.733          0.000000    0.1680    -5.376
# 2        0.000421         0.511   0.822          0.019700    0.0899    -4.785
# 3        0.000537         0.545   0.885          0.000056    0.3850    -5.968
# 4        0.000656         0.588   0.721          0.000000    0.1310    -5.579
# ..            ...           ...     ...               ...       ...       ...
# 525      0.111000         0.668   0.672          0.000000    0.3290    -4.931
# 526      0.004520         0.563   0.934          0.000807    0.1030    -3.629
# 527      0.637000         0.612   0.394          0.000000    0.1470    -5.723
# 528      0.003490         0.483   0.751          0.000000    0.1280    -5.726
# 529      0.040200         0.459   0.753          0.000000    0.0863    -3.827
#
#      speechiness    tempo  valence  popularity  duration_ms  release_month  \
# 0         0.0327  116.998    0.685          79       212600             10
# 1         0.0670   96.057    0.701          79       231833             10
# 2         0.0397   94.868    0.305          80       231000             10
# 3         0.0447   92.021    0.206          79       235800             10
# 4         0.0317   96.997    0.520          78       193289             10
# ..           ...      ...      ...         ...          ...            ...
# 525       0.0303   89.011    0.539          76       201106             10
# 526       0.0646  143.964    0.518          61       213053             10
# 527       0.0243   96.001    0.233          58       203226             10
# 528       0.0365  156.092    0.268          56       220146             10
# 529       0.0537  199.997    0.483          57       179066             10
#
#      release_year
# 0            2023
# 1            2023
# 2            2023
# 3            2023
# 4            2023
# ..            ...
# 525          2006
# 526          2006
# 527          2006
# 528          2006
# 529          2006
#
# [530 rows x 18 columns]

# %%
# Also we convert duration_ms to duration_s
df['duration_s'] = df['duration_ms'] // 1000
df
# Out:
#      Unnamed: 0                                           name  \
# 0             0         Welcome To New York (Taylor's Version)
# 1             1                 Blank Space (Taylor's Version)
# 2             2                       Style (Taylor's Version)
# 3             3            Out Of The Woods (Taylor's Version)
# 4             4  All You Had To Do Was Stay (Taylor's Version)
# ..          ...                                            ...
# 525         525                                       Our Song
# 526         526                  I'm Only Me When I'm With You
# 527         527                                      Invisible
# 528         528                         A Perfectly Good Heart
# 529         529           Teardrops on My Guitar - Pop Version
#
#                                 album release_date  track_number  \
# 0    1989 (Taylor's Version) [Deluxe]   2023-10-27             1
# 1    1989 (Taylor's Version) [Deluxe]   2023-10-27             2
# 2    1989 (Taylor's Version) [Deluxe]   2023-10-27             3
# 3    1989 (Taylor's Version) [Deluxe]   2023-10-27             4
# 4    1989 (Taylor's Version) [Deluxe]   2023-10-27             5
# ..                                ...          ...           ...
# 525                      Taylor Swift   2006-10-24            11
# 526                      Taylor Swift   2006-10-24            12
# 527                      Taylor Swift   2006-10-24            13
# 528                      Taylor Swift   2006-10-24            14
# 529                      Taylor Swift   2006-10-24            15
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.009420         0.757   0.610          0.000037    0.3670    -4.840
# 1        0.088500         0.733   0.733          0.000000    0.1680    -5.376
# 2        0.000421         0.511   0.822          0.019700    0.0899    -4.785
# 3        0.000537         0.545   0.885          0.000056    0.3850    -5.968
# 4        0.000656         0.588   0.721          0.000000    0.1310    -5.579
# ..            ...           ...     ...               ...       ...       ...
# 525      0.111000         0.668   0.672          0.000000    0.3290    -4.931
# 526      0.004520         0.563   0.934          0.000807    0.1030    -3.629
# 527      0.637000         0.612   0.394          0.000000    0.1470    -5.723
# 528      0.003490         0.483   0.751          0.000000    0.1280    -5.726
# 529      0.040200         0.459   0.753          0.000000    0.0863    -3.827
#
#      speechiness    tempo  valence  popularity  duration_ms  release_month  \
# 0         0.0327  116.998    0.685          79       212600             10
# 1         0.0670   96.057    0.701          79       231833             10
# 2         0.0397   94.868    0.305          80       231000             10
# 3         0.0447   92.021    0.206          79       235800             10
# 4         0.0317   96.997    0.520          78       193289             10
# ..           ...      ...      ...         ...          ...            ...
# 525       0.0303   89.011    0.539          76       201106             10
# 526       0.0646  143.964    0.518          61       213053             10
# 527       0.0243   96.001    0.233          58       203226             10
# 528       0.0365  156.092    0.268          56       220146             10
# 529       0.0537  199.997    0.483          57       179066             10
#
#      release_year  duration_s
# 0            2023         212
# 1            2023         231
# 2            2023         231
# 3            2023         235
# 4            2023         193
# ..            ...         ...
# 525          2006         201
# 526          2006         213
# 527          2006         203
# 528          2006         220
# 529          2006         179
#
# [530 rows x 19 columns]

# %%
# And we drop the release date and duration ms columns
df = df.drop(['release_date', 'duration_ms'], axis=1)
df
# Out:
#      Unnamed: 0                                           name  \
# 0             0         Welcome To New York (Taylor's Version)
# 1             1                 Blank Space (Taylor's Version)
# 2             2                       Style (Taylor's Version)
# 3             3            Out Of The Woods (Taylor's Version)
# 4             4  All You Had To Do Was Stay (Taylor's Version)
# ..          ...                                            ...
# 525         525                                       Our Song
# 526         526                  I'm Only Me When I'm With You
# 527         527                                      Invisible
# 528         528                         A Perfectly Good Heart
# 529         529           Teardrops on My Guitar - Pop Version
#
#                                 album  track_number  acousticness  \
# 0    1989 (Taylor's Version) [Deluxe]             1      0.009420
# 1    1989 (Taylor's Version) [Deluxe]             2      0.088500
# 2    1989 (Taylor's Version) [Deluxe]             3      0.000421
# 3    1989 (Taylor's Version) [Deluxe]             4      0.000537
# 4    1989 (Taylor's Version) [Deluxe]             5      0.000656
# ..                                ...           ...           ...
# 525                      Taylor Swift            11      0.111000
# 526                      Taylor Swift            12      0.004520
# 527                      Taylor Swift            13      0.637000
# 528                      Taylor Swift            14      0.003490
# 529                      Taylor Swift            15      0.040200
#
#      danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0           0.757   0.610          0.000037    0.3670    -4.840       0.0327
# 1           0.733   0.733          0.000000    0.1680    -5.376       0.0670
# 2           0.511   0.822          0.019700    0.0899    -4.785       0.0397
# 3           0.545   0.885          0.000056    0.3850    -5.968       0.0447
# 4           0.588   0.721          0.000000    0.1310    -5.579       0.0317
# ..            ...     ...               ...       ...       ...          ...
# 525         0.668   0.672          0.000000    0.3290    -4.931       0.0303
# 526         0.563   0.934          0.000807    0.1030    -3.629       0.0646
# 527         0.612   0.394          0.000000    0.1470    -5.723       0.0243
# 528         0.483   0.751          0.000000    0.1280    -5.726       0.0365
# 529         0.459   0.753          0.000000    0.0863    -3.827       0.0537
#
#        tempo  valence  popularity  release_month  release_year  duration_s
# 0    116.998    0.685          79             10          2023         212
# 1     96.057    0.701          79             10          2023         231
# 2     94.868    0.305          80             10          2023         231
# 3     92.021    0.206          79             10          2023         235
# 4     96.997    0.520          78             10          2023         193
# ..       ...      ...         ...            ...           ...         ...
# 525   89.011    0.539          76             10          2006         201
# 526  143.964    0.518          61             10          2006         213
# 527   96.001    0.233          58             10          2006         203
# 528  156.092    0.268          56             10          2006         220
# 529  199.997    0.483          57             10          2006         179
#
# [530 rows x 17 columns]

# %% [markdown]
# ## Data exploration and Visualization

# %% [markdown]
# ### Number of Albums in Spotify

# %%
number_of_albums = df['album'].nunique()
albums_name = df['album'].unique()

print(f"Number of Albums: {number_of_albums}, Album names: {list(albums_name)}")
# Out:
# Number of Albums: 27, Album names: ["1989 (Taylor's Version) [Deluxe]", "1989 (Taylor's Version)", "Speak Now (Taylor's Version)", 'Midnights (The Til Dawn Edition)', 'Midnights (3am Edition)', 'Midnights', "Red (Taylor's Version)", "Fearless (Taylor's Version)", 'evermore (deluxe version)', 'evermore', 'folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]', 'folklore (deluxe version)', 'folklore', 'Lover', 'reputation', 'reputation Stadium Tour Surprise Song Playlist', '1989 (Deluxe Edition)', '1989', 'Red (Deluxe Edition)', 'Red', 'Speak Now World Tour Live', 'Speak Now (Deluxe Edition)', 'Speak Now', 'Fearless Platinum Edition', 'Fearless', 'Live From Clear Channel Stripped 2008', 'Taylor Swift']

# %% [markdown]
# ### Number of musics per album

# %%
music_per_album = df['album'].value_counts()
music_per_album
# Out:
# reputation Stadium Tour Surprise Song Playlist                                         46
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]    34
# Red (Taylor's Version)                                                                 30
# Fearless (Taylor's Version)                                                            26
# Midnights (The Til Dawn Edition)                                                       23
# 1989 (Taylor's Version) [Deluxe]                                                       22
# Speak Now (Taylor's Version)                                                           22
# Red (Deluxe Edition)                                                                   22
# 1989 (Taylor's Version)                                                                21
# Midnights (3am Edition)                                                                20
# Speak Now (Deluxe Edition)                                                             20
# Fearless Platinum Edition                                                              19
# 1989 (Deluxe Edition)                                                                  19
# Lover                                                                                  18
# folklore (deluxe version)                                                              17
# evermore (deluxe version)                                                              17
# folklore                                                                               16
# Red                                                                                    16
# Speak Now World Tour Live                                                              16
# reputation                                                                             15
# evermore                                                                               15
# Taylor Swift                                                                           15
# Speak Now                                                                              14
# 1989                                                                                   13
# Midnights                                                                              13
# Fearless                                                                               13
# Live From Clear Channel Stripped 2008                                                   8
# Name: album, dtype: int64

# %%
most_music_albums = music_per_album.head(10)
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title("10 Albums with most tracks")
sns.barplot(x=most_music_albums.index, y=most_music_albums);

# %% [markdown]
# ### Albums Danceability

# %%
album_detail_danceability = pd.DataFrame({
    'album': music_per_album.index,
    'danceability': df.groupby('album')['danceability'].mean(),
    'release_year': df.groupby('album')['release_year'].first().values
})
album_detail_danceability = album_detail_danceability.sort_values('release_year', ascending=True)
album_detail_danceability
# Out:
#                                                                                                 album  \
# album
# Taylor Swift                                                                               reputation
# Fearless                                                             Midnights (The Til Dawn Edition)
# Fearless Platinum Edition                                                Speak Now (Taylor's Version)
# Live From Clear Channel Stripped 2008                                            Red (Deluxe Edition)
# Speak Now World Tour Live                                                   Speak Now World Tour Live
# Speak Now (Deluxe Edition)                                                                   folklore
# Speak Now                                                                   evermore (deluxe version)
# Red (Deluxe Edition)                                                                            Lover
# Red                                                                             1989 (Deluxe Edition)
# 1989                                                   reputation Stadium Tour Surprise Song Playlist
# 1989 (Deluxe Edition)                               folklore: the long pond studio sessions (from ...
# reputation Stadium Tour Surprise Song Playlist                  Live From Clear Channel Stripped 2008
# reputation                                                                                   Fearless
# Lover                                                                         1989 (Taylor's Version)
# folklore: the long pond studio sessions (from t...                                          Midnights
# folklore (deluxe version)                                                                        1989
# folklore                                                                                    Speak Now
# evermore                                                                                     evermore
# Red (Taylor's Version)                                                      folklore (deluxe version)
# Fearless (Taylor's Version)                                          1989 (Taylor's Version) [Deluxe]
# evermore (deluxe version)                                                                Taylor Swift
# Midnights (3am Edition)                                                    Speak Now (Deluxe Edition)
# Midnights                                                                     Midnights (3am Edition)
# Speak Now (Taylor's Version)                                                                      Red
# 1989 (Taylor's Version) [Deluxe]                                          Fearless (Taylor's Version)
# Midnights (The Til Dawn Edition)                                            Fearless Platinum Edition
# 1989 (Taylor's Version)                                                        Red (Taylor's Version)
#
#                                                     danceability  release_year
# album
# Taylor Swift                                            0.545267          2006
# Fearless                                                0.592769          2008
# Fearless Platinum Edition                               0.575947          2008
# Live From Clear Channel Stripped 2008                   0.548125          2008
# Speak Now World Tour Live                               0.441312          2010
# Speak Now (Deluxe Edition)                              0.556450          2010
# Speak Now                                               0.544929          2010
# Red (Deluxe Edition)                                    0.633364          2012
# Red                                                     0.622875          2012
# 1989                                                    0.649385          2014
# 1989 (Deluxe Edition)                                   0.633211          2014
# reputation Stadium Tour Surprise Song Playlist          0.596413          2017
# reputation                                              0.657933          2017
# Lover                                                   0.658222          2019
# folklore: the long pond studio sessions (from t...      0.551441          2020
# folklore (deluxe version)                               0.541941          2020
# folklore                                                0.567875          2020
# evermore                                                0.518867          2020
# Red (Taylor's Version)                                  0.576967          2021
# Fearless (Taylor's Version)                             0.551038          2021
# evermore (deluxe version)                               0.526824          2021
# Midnights (3am Edition)                                 0.626650          2022
# Midnights                                               0.638538          2022
# Speak Now (Taylor's Version)                            0.551364          2023
# 1989 (Taylor's Version) [Deluxe]                        0.619455          2023
# Midnights (The Til Dawn Edition)                        0.624130          2023
# 1989 (Taylor's Version)                                 0.632095          2023

# %% [markdown]
# #### Line Chart (Albums based on the year released)

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title("Average danceability of albums")
sns.lineplot(x=album_detail_danceability['album'], y=album_detail_danceability['danceability']);

# %% [markdown]
# #### Most and Least danceable albums

# %%
album_detail_danceability = album_detail_danceability.sort_values('danceability', ascending=True)
least_danceable_albums = list(album_detail_danceability['album'].head(3).values)
most_danceable_albums = list(album_detail_danceability['album'].tail(3).values)
most_danceable_albums.reverse() # We reverse it so the 0 index is the most danceable one!
print(f"Most Danceable Albums: {most_danceable_albums}")
print(f"Least Danceable Albums: {least_danceable_albums}")
# Out:
# Most Danceable Albums: ["1989 (Taylor's Version)", 'Fearless', 'reputation Stadium Tour Surprise Song Playlist']
# Least Danceable Albums: ['Speak Now World Tour Live', 'evermore', 'Taylor Swift']

# %% [markdown]
# ### Albums Energy

# %%
album_detail_energy = pd.DataFrame({
    'album': music_per_album.index,
    'energy': df.groupby('album')['energy'].mean(),
    'release_year': df.groupby('album')['release_year'].first().values
    
})
album_detail_energy = album_detail_energy.sort_values('release_year', ascending=True)
album_detail_energy
# Out:
#                                                                                                 album  \
# album
# Taylor Swift                                                                               reputation
# Fearless                                                             Midnights (The Til Dawn Edition)
# Fearless Platinum Edition                                                Speak Now (Taylor's Version)
# Live From Clear Channel Stripped 2008                                            Red (Deluxe Edition)
# Speak Now World Tour Live                                                   Speak Now World Tour Live
# Speak Now (Deluxe Edition)                                                                   folklore
# Speak Now                                                                   evermore (deluxe version)
# Red (Deluxe Edition)                                                                            Lover
# Red                                                                             1989 (Deluxe Edition)
# 1989                                                   reputation Stadium Tour Surprise Song Playlist
# 1989 (Deluxe Edition)                               folklore: the long pond studio sessions (from ...
# reputation Stadium Tour Surprise Song Playlist                  Live From Clear Channel Stripped 2008
# reputation                                                                                   Fearless
# Lover                                                                         1989 (Taylor's Version)
# folklore: the long pond studio sessions (from t...                                          Midnights
# folklore (deluxe version)                                                                        1989
# folklore                                                                                    Speak Now
# evermore                                                                                     evermore
# Red (Taylor's Version)                                                      folklore (deluxe version)
# Fearless (Taylor's Version)                                          1989 (Taylor's Version) [Deluxe]
# evermore (deluxe version)                                                                Taylor Swift
# Midnights (3am Edition)                                                    Speak Now (Deluxe Edition)
# Midnights                                                                     Midnights (3am Edition)
# Speak Now (Taylor's Version)                                                                      Red
# 1989 (Taylor's Version) [Deluxe]                                          Fearless (Taylor's Version)
# Midnights (The Til Dawn Edition)                                            Fearless Platinum Edition
# 1989 (Taylor's Version)                                                        Red (Taylor's Version)
#
#                                                       energy  release_year
# album
# Taylor Swift                                        0.664267          2006
# Fearless                                            0.637308          2008
# Fearless Platinum Edition                           0.601053          2008
# Live From Clear Channel Stripped 2008               0.598875          2008
# Speak Now World Tour Live                           0.650250          2010
# Speak Now (Deluxe Edition)                          0.647900          2010
# Speak Now                                           0.663286          2010
# Red (Deluxe Edition)                                0.600773          2012
# Red                                                 0.619563          2012
# 1989                                                0.699077          2014
# 1989 (Deluxe Edition)                               0.624842          2014
# reputation Stadium Tour Surprise Song Playlist      0.653239          2017
# reputation                                          0.582867          2017
# Lover                                               0.545222          2019
# folklore: the long pond studio sessions (from t...  0.373412          2020
# folklore (deluxe version)                           0.415824          2020
# folklore                                            0.425063          2020
# evermore                                            0.491333          2020
# Red (Taylor's Version)                              0.586900          2021
# Fearless (Taylor's Version)                         0.639115          2021
# evermore (deluxe version)                           0.494059          2021
# Midnights (3am Edition)                             0.451150          2022
# Midnights                                           0.410154          2022
# Speak Now (Taylor's Version)                        0.655455          2023
# 1989 (Taylor's Version) [Deluxe]                    0.664318          2023
# Midnights (The Til Dawn Edition)                    0.470522          2023
# 1989 (Taylor's Version)                             0.665143          2023

# %% [markdown]
# #### Most and Least Energetic Albums

# %%
album_detail_energy = album_detail_energy.sort_values('energy', ascending=True)
least_energetic_albums = list(album_detail_energy['album'].head(3).values)
most_energetic_albums = list(album_detail_energy['album'].tail(3).values)
most_energetic_albums.reverse() # We reverse it so the 0 index is the most danceable one!
print(f"Most Energetic Albums: {most_energetic_albums}")
print(f"Least Energetic Albums: {least_energetic_albums}")
# Out:
# Most Energetic Albums: ['reputation Stadium Tour Surprise Song Playlist', "Red (Taylor's Version)", "Fearless (Taylor's Version)"]
# Least Energetic Albums: ['Midnights', 'Midnights (3am Edition)', '1989']

# %% [markdown]
# #### Line Chart (Albums based on the year released)

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title("Average energy of albums")
sns.lineplot(x=album_detail_energy['album'], y=album_detail_energy['energy']);

# %% [markdown]
# ### Albumes Positiveness

# %%
album_detail_valence = pd.DataFrame({
    'album': music_per_album.index,
    'valence': df.groupby('album')['valence'].mean(),
    'release_year': df.groupby('album')['release_year'].first().values
    
})
album_detail_valence = album_detail_valence.sort_values('release_year', ascending=True)
album_detail_valence
# Out:
#                                                                                                 album  \
# album
# Taylor Swift                                                                               reputation
# Fearless                                                             Midnights (The Til Dawn Edition)
# Fearless Platinum Edition                                                Speak Now (Taylor's Version)
# Live From Clear Channel Stripped 2008                                            Red (Deluxe Edition)
# Speak Now World Tour Live                                                   Speak Now World Tour Live
# Speak Now (Deluxe Edition)                                                                   folklore
# Speak Now                                                                   evermore (deluxe version)
# Red (Deluxe Edition)                                                                            Lover
# Red                                                                             1989 (Deluxe Edition)
# 1989                                                   reputation Stadium Tour Surprise Song Playlist
# 1989 (Deluxe Edition)                               folklore: the long pond studio sessions (from ...
# reputation Stadium Tour Surprise Song Playlist                  Live From Clear Channel Stripped 2008
# reputation                                                                                   Fearless
# Lover                                                                         1989 (Taylor's Version)
# folklore: the long pond studio sessions (from t...                                          Midnights
# folklore (deluxe version)                                                                        1989
# folklore                                                                                    Speak Now
# evermore                                                                                     evermore
# Red (Taylor's Version)                                                      folklore (deluxe version)
# Fearless (Taylor's Version)                                          1989 (Taylor's Version) [Deluxe]
# evermore (deluxe version)                                                                Taylor Swift
# Midnights (3am Edition)                                                    Speak Now (Deluxe Edition)
# Midnights                                                                     Midnights (3am Edition)
# Speak Now (Taylor's Version)                                                                      Red
# 1989 (Taylor's Version) [Deluxe]                                          Fearless (Taylor's Version)
# Midnights (The Til Dawn Edition)                                            Fearless Platinum Edition
# 1989 (Taylor's Version)                                                        Red (Taylor's Version)
#
#                                                      valence  release_year
# album
# Taylor Swift                                        0.426533          2006
# Fearless                                            0.384231          2008
# Fearless Platinum Edition                           0.380053          2008
# Live From Clear Channel Stripped 2008               0.472125          2008
# Speak Now World Tour Live                           0.290250          2010
# Speak Now (Deluxe Edition)                          0.416950          2010
# Speak Now                                           0.420286          2010
# Red (Deluxe Edition)                                0.468191          2012
# Red                                                 0.496938          2012
# 1989                                                0.462600          2014
# 1989 (Deluxe Edition)                               0.454211          2014
# reputation Stadium Tour Surprise Song Playlist      0.446457          2017
# reputation                                          0.293400          2017
# Lover                                               0.481444          2019
# folklore: the long pond studio sessions (from t...  0.337676          2020
# folklore (deluxe version)                           0.361353          2020
# folklore                                            0.381250          2020
# evermore                                            0.420600          2020
# Red (Taylor's Version)                              0.424600          2021
# Fearless (Taylor's Version)                         0.421923          2021
# evermore (deluxe version)                           0.433529          2021
# Midnights (3am Edition)                             0.282530          2022
# Midnights                                           0.223531          2022
# Speak Now (Taylor's Version)                        0.401782          2023
# 1989 (Taylor's Version) [Deluxe]                    0.412627          2023
# Midnights (The Til Dawn Edition)                    0.278243          2023
# 1989 (Taylor's Version)                             0.422371          2023

# %% [markdown]
# #### Least and Most positive albums

# %%
album_detail_valence = album_detail_valence.sort_values('valence', ascending=True)
least_positive_albums = list(album_detail_valence['album'].head(3).values)
most_positive_albums = list(album_detail_valence['album'].tail(3).values)
most_positive_albums.reverse() # We reverse it so the 0 index is the most danceable one!
print(f"Most Positive Albums: {most_positive_albums}")
print(f"Least Positive Albums: {least_positive_albums}")
# Out:
# Most Positive Albums: ['1989 (Deluxe Edition)', "1989 (Taylor's Version)", 'Red (Deluxe Edition)']
# Least Positive Albums: ['Midnights (3am Edition)', 'Fearless Platinum Edition', 'Speak Now (Deluxe Edition)']

# %% [markdown]
# #### Bar Graph (Albums sorted by year)

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title("Average positiveness of albums")
sns.lineplot(x=album_detail_valence['album'], y=album_detail_valence['valence']);
